# %% [markdown]
# # Lectures 3 and 4: Origins of Crystal Structure
# ---

# %% [markdown]
# # Where We Left Off
# ---
#
# Key points:
#
# - Bonds have character
# - Ionic bonds are directional y/n , and why?
# - Covalent bonds are directional y/n , and why?
# - Metallic bonds are directional y/n , and why?
#
#
# - Questions you should be able to answer:
#  - Based on our discussion last time, what do the above all share in common?
#  - Are the other types of bonds? IF not for electron transfer, where do they come from?

# %% [markdown]
# # Bonds Lead To Structure
# ---
#
# ## Where does symmetry come from?
#
# - What sets the distance for a bond?
#  - Lecture 1
# - What was the position for a bond?
#  - Lecture 2
# - Does a bond want to be at a separate distance.
#  - Not really
#   - See depth and width of potential well
#
# So if bonds what to be a given distance, then if we back atoms, they should form order, yes? Why?

# %% [markdown]
# ## The Unit Cell
#
# What makes a unit cell
#
# <img src='https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/unit_cell_example.png'>
#
# why is "f" bad?
#
# [Source](http://n.ethz.ch/~nielssi/download/4.%20Semester/AC%20II/Unterlagen/symmetry_2D_3.pdf)

# %% [markdown]
# ## Simple Views on Crystal Systems
#
# In class we'll work our way down these and discuss decreasing symmetry.
#
# There are 7 Crystal Families defined by their similarities in lattice parameter and angles in 3 dimensions. If we add possible points on face centers and/or the body center, we get a total of 14 primitive lattice types: these are the _Bravais Lattices_

# %% [markdown]
# System                  | Lengths / Angles                       | Bravais Lattice                                            | Lattice Symbol
# ---                     | ---                                    |---                                                         | ---
# Cubic                   | a=b=c $\alpha$=$\beta$=$\gamma$=90˚    |1. Simple<br>2. Body Centered<br>3. Face Centered<br>     |P<br>I<br>F
# Tetragonal              | a=b≠c$\alpha$=$\beta$=$\gamma$=90˚     |4. Simple<br>5. Body Centered<br>|P<br>I
# Orthorhombic            | a≠b≠c $\alpha$=$\beta$=$\gamma$=90˚    |6. Simple<br>7. Body Centered<br>8. Base Centered<br>9. Face Centered<br> |P<br>I<br>C<br>F
# Rhombohedral / Trigonal | a=b=c $\alpha$=$\beta$=$\gamma$≠90˚    |10. Simple<br>                                                  |R<br>
# Hexagonal               | a=b≠c $\alpha$=$\beta$=90˚$\gamma$=120˚|11. Simple<br>                                                  |P<br>
# Monoclinic              | a≠b≠c $\alpha$=$\gamma$=90˚$\beta$≠90˚ |12. Simple<br>13. Base Centered<br>                             |P<br>C
# Triclinc                | a≠b≠c $\alpha$≠$\beta$≠$\gamma$≠90˚    |14. Simple<br>                                                  |P

# %% [markdown]
# ## Symmetry Operations
#
# Per [wikidpedia](https://en.wikipedia.org/wiki/Crystallographic_point_group)
#
# >a crystallographic point group is a set of symmetry operations, like rotations or reflections, that leave a central point fixed while moving other directions and faces of the crystal to the positions of features of the same kind.
#
# A point group is formaton that effectively defined by its abilities to be translated and/or rotated by given operation be indistinguisbable from the state before the operation.
#
# For example, let's consider symmetry options in two dimensions (taken from http://n.ethz.ch/~nielssi/download/4.%20Semester/AC%20II/Unterlagen/symmetry_2D_3.pdf)
#
# ### 1. Translation (2D/3D)
# Translation moves all the points in the asymmetric unit the same distance in the same direction.
# <img src='https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/SymExamples/sym1.png'>
#
# ### 2. Rotations (2D/3D)
#  A rotation turns all the points in the asymmetric unit around one axis, the center of rotation.
# <img src='https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/SymExamples/sym2.png'>
#
# ### 3. Reflections (2D/3D)
# A reflection flips all points in the asymmetric unit over a line called mirror.
# <img src='https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/SymExamples/sym3.png'>
#
#
# ### 4. Glide Reflections (2D/3D)
# Glide reflection reflects the asymmetric unit across a mirror and then translates it parallel to the mirror
# <img src='https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/SymExamples/sym4.png'>
#
#
# ### 5. Inversion center (3D)
#
# ### 6. Rotoinversions (3D)
#
# ### 7. Screw axes (3D)

# %% [markdown]
# ## Point Group Symmetry
#
# **Point Group Symmetry Does Not Consider Translation**
#
# Notation | Example
# --| --
# 1   | 1 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/1.png">
# 2   | 2 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/2.png">
# 3   | 3 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/3.png">
# 4   | 4 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/4.png">
# 6   | 6 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/6.png">
# m   | 1 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/m.png">
# 2mm | 2 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/2mm.png">
# 3m  | 3 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/3m.png">
# 4mm | 4 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/4mm.png">
# 6mm | 6 fold axis <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/PG/6mm.png">

# %% [markdown]
# These are the plane **point groups** (2D)
#
# If we take the 2D projections of the above 3D lattice types, we can reduce to
#
# Name           | Propreties
# --             | --
# Oblique        | a≠b, ≠90˚
# Rectangular    | a≠b, =90˚
# Square         | a=b, =90˚
# Diamond        | a≠b, =90˚
# Hexagonal      | a=b, =120˚
#
# When we combine the 2d point groups with the 2d lattices, we get 17 plane groups.

# %% [markdown]
# ## Putting it together
#
# When we combine lattices with a basis and motif, we get crystal structures.  Here's a cute example
#
# <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/lattice_basis_CS.png">
# [Source](http://n.ethz.ch/~nielssi/download/4.%20Semester/AC%20II/Unterlagen/symmetry_2D_3.pdf)

# %% [markdown]
# ## What about Motifs?
#
# Let's assume that these letters are motifs
#
# PG   | Example
# --   | --
# 1    | 9
# 2mm  | O
# 4mm  | x

# %% [markdown]
# ## Taken Together, here are the 17 space groups in 2D
#
#
# <img src="https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/17_space_groups.png">
# [src](http://n.ethz.ch/~nielssi/download/4.%20Semester/AC%20II/Unterlagen/symmetry_2D_3.pdf)

# %%
# %matplotlib inline
import sys
sys.path.append("/pithy/code/")
from pithy import *
from PIL import Image
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
import urllib, cStringIO
import scipy.ndimage
figure(figsize=(15,15))

#Choose 1-5
f1 = "https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/SGExamples/SGexample01.png"
f = cStringIO.StringIO(urllib.urlopen(f1).read())
img = Image.open(f)
arr1 = array(img)
arr2 = scipy.ndimage.interpolation.rotate(arr1,180)
subplot(1,2,1)
imshow(arr1)
xticks([])
yticks([])
subplot(1,2,2)
imshow(arr2)
xticks([])
yticks([])
show()

# %% [markdown]
# ## A Note on Quasicrystals
#
# Quasicrystal have interesting rotational symmetries (5 fold, 7 fold) but no translational symmetry, so they are not lattices in the traditional sense.  Their existence was quite controversial, but eventually yield a Nobel Prize for Shechtman in [2011](https://www.nobelprize.org/nobel_prizes/chemistry/laureates/2011/popular-chemistryprize2011.pdf)
#
# This is an example of 10 fold symmetry.
#
# <img src='https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/Shechtman.png'>

# %%
figure(figsize=(15,15))
f1 = "https://drops.steingart.princeton.edu/MSE501_Fall_2017/Images/Shechtman.png"
f = cStringIO.StringIO(urllib.urlopen(f1).read())
img = Image.open(f)
arr1 = array(img)
mx = 5
for i in range(mx):
    subplot(1,mx,i+1)
    ang = 36
    arrd = scipy.ndimage.interpolation.rotate(arr1,ang*i)
    imshow(arrd)
    title("%i degrees" %(ang*i))
    xticks([])
    yticks([])
show()

# %% [markdown]
# ## Defects
#
# At what point is a crystal the most "determined" -> 0 K
#
# As we heat bonds up what happens? -> there become two "happy" places in the potential well
#
# There is a probability introduced by this that an atom is "missing" from the lattice that scales as
#
# $$n = n_0 \exp \left(\frac{-U}{kT}\right)$$

# %% [markdown]
# ## Crystal Indicies
#
# So, critical to our understanding of bonding _at equilibrium_ is the ability to example crystal structures, and atomic positions.  Crystal indices are the notation we use to do this.
#
# We use the notations _u_, _v_, _w_ to denote the 3 vectors of cystal, and they are of spaces _a_,_b_ and _c_,  such that we have spacings
#
# $$u\times a,v\times b,w\times c $$
#
# This allows us, based on out directions outlined way back, to note that equal indicies do not note equal displacements: everything is normalized against the lengths in the unit cell.
#
# When describing a _vector_ in a unit cell we can decribe a line
#
# $$[\frac{1}{2}\frac{1}{2}1]$$ but in general the smallest notation of whole numbers is preferred, $$[112]$$ rather than say the equivalent $$[224]$$
#
# Based on our discussion above, in many crystals will have equivalencies, such that the vectures in a system (say, simple cubic)
#
# $$[111],[1\bar{1}1],[\bar{1}\bar{1}1],[\bar{1}11]$$
#
# can be further reduced to
#
# $$< 111 >$$
#
# We can then define _planes_ by the miller indices _h_,_k_, and _l_ where a plane intersecting _x_ at 1/_h_, _y_ at 1/_k_, _z_ at 1/_l_ is described by
# $$(hkl)$$ and hexagnol planes add an _i_ so $$(hkil)$$such that $$h+k=-i$$
#
# and so like vectors, planes of a form can be described by $$\{hkl\}$$ so
# $$(100), (010), (\bar{1}00), (0\bar{1}0), (001), (00\bar{1})$$
# can all be be described by $$\{100\}$$
#
# ## Spacing in Crystals
#
# System      |Spacing Between Planes
# --          | --
# Cubic       | $\frac{1}{d^2} = \frac{h^2+k^2+l^2}{a^2}$
# Tetragonal  | $\frac{1}{d^2} = \frac{h^2+k^2}{a^2}+\frac{l^2}{c^2}$
# Hexagonal   | $\frac{1}{d^2} = \frac{4}{3}\frac{h^2+hk+k^2}{a^2}+\frac{l^2}{c^2}$
# Rhombohedral| $\frac{1}{d^2} = \frac{(h^2+k^2+l^2)\sin^2\alpha + 2(hk+kl+hl)(\cos^2 \alpha-\cos \alpha)}{a^2(1-3\cos^2\alpha+2\cos^3\alpha)}$
# Orthorhombic| $\frac{1}{d^2} = \frac{h^2}{a^2}+\frac{k^2}{b^2}+\frac{l^2}{c^2}$
#
#
#
# ## Metallic Crystalls
#
# Because of the lack of strong directional forces on bonding, most pure metals form BCC,FCC and HCP structures.
#
# ### FCC Metals
#
# How many atoms per unit cell? (4)
# $\gamma$-Fe,Al,Ni,Cu,Pt,Au
#
# ### HCP Metals
#
# How many atoms per unit cell? (2)
# $\alpha$-Ti,Mg,Be,Zr,Zn
#
#
# ### BCC Metals
#
# W,V,Cr,$\alpha$-Fe
