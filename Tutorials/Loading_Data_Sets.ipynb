# %% [markdown]
# ## Loading External Datasets

# %% [markdown]
# First import the libraries you need.

# %%
import sys
sys.path.append("/pithy/code")
from pithy import *
# %matplotlib inline
import pandas as pd

# %% [markdown]
# Then load the dataset from the correct location

# %%
df = pd.read_csv("/notebooks/class_folder/Datasets/hw2_mystery.dat")

# %% [markdown]
# Then plot

# %%
plot(df['2Theta'],df['Count'],color="black")
ylabel("Counts")
xlabel("Angle (2$\\theta $)")
# Out:
# Text(0.5,0,'Angle (2$\\theta $)')
